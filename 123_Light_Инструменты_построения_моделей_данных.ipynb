# %% [markdown]
# <a href="https://colab.research.google.com/github/10100111/Display-of-HW1/blob/main/123_Light_%D0%98%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B_%D0%BF%D0%BE%D1%81%D1%82%D1%80%D0%BE%D0%B5%D0%BD%D0%B8%D1%8F_%D0%BC%D0%BE%D0%B4%D0%B5%D0%BB%D0%B5%D0%B9_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание Ultra Lite
#
# Макс 10 баллов
#
# Используя сайт https://www.themoviedb.org/person?language=en-US, предложите ER диаграмму, которая будет включать как минимум следующие сущности: Movie (фильмы), Genre (жанры), TV Series (сериалы), Seasons (сезоны), Episodes (эпизоды), Movie Peoples (актеры), Actor’s Role (роль, которую играл актер в фильме/сериале).
# Нарисуйте правильную (используйте правильные обозначения!) диаграмму в любом графическом редакторе (можно Power point). Задайте каждой сущности как минимум по 2 атрибута и пропишите связи (Relationship).
#
#
#
# Разбор: https://docs.google.com/document/d/1Sy1WLEirM1BFBKCTvypWv5kaVNudJc2s/edit?usp=sharing&ouid=108887502603907522266&rtpof=true&sd=true

# %% [markdown]
# Задание Lite
#
# Макс 10 баллов
#
# Выполните задание ultra light в любом редакторе схем данных.
#
# Разбор: https://drive.google.com/file/d/1dh_ELb9-D2bJRHtjnqqV41FmlzxLVGfu/view?usp=sharing

# %% [markdown]
# Задание выполнено с помощью фреймворка https://app.creately.com/

# %% [markdown]
# ![Ultra Light (1).jpg](data:image/jpeg;base64,...)
