# %% [markdown]
# <a href="https://colab.research.google.com/github/10100111/Display-of-HW1/blob/main/120_Pro_%D0%A1%D1%85%D0%B5%D0%BC%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание Pro
#
# Возьмите схему данных из задания Light. Приведите таблицу Customers в 3НФ - третью Нормальную Форму (создайте дополнительные таблицы , если необходимо). Создайте полученную схему в любой программе для создания схем данных. Если используете собственную программу, приложите ссылку на нее.
#
# Разбор: https://drive.google.com/file/d/1O7UOoHrdWrCzVHJkZMTMufdCtXwNINOy/view?usp=sharing

# %% [markdown]
# ![hw_pro.png](data:image/png;base64,...)

# %% [markdown]
# В моем понимании отрасль не поменяется у компании и это также часть реквизитов самой компании. Или я что-то не поняла. В разборе не такой ответ.
