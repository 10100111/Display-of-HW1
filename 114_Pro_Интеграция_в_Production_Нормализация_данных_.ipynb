# %% [markdown]
# <a href="https://colab.research.google.com/github/10100111/Display-of-HW1/blob/main/114_Pro_%D0%98%D0%BD%D1%82%D0%B5%D0%B3%D1%80%D0%B0%D1%86%D0%B8%D1%8F_%D0%B2_Production_%D0%9D%D0%BE%D1%80%D0%BC%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Занятие 6. PRO
# Преобразуйте отношение в таблице к 1 НФ, 2 НФ, 3 НФ

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(columns=['Full Names','Physical Address','Movies rented','Salutation'],data=[['Janet Jones','First Street Plot N0 4', 'Titanic, The girl next door', 'Ms.'],
                                                                                             ['Robert Phil','3rd Street 34', 'Blade 3, Casablanca','Mr.'],
                                                                                             ['Robert Phil','5th Avenue', 'Titanic','Mr.']])
df
# Out:
#     Full Names        Physical Address                Movies rented Salutation
# 0  Janet Jones  First Street Plot N0 4  Titanic, The girl next door        Ms.
# 1  Robert Phil           3rd Street 34          Blade 3, Casablanca        Mr.
# 2  Robert Phil              5th Avenue                      Titanic        Mr.

# %% [markdown]
# ## 1НФ

# %%
df=pd.DataFrame(columns=['ID','Full Names','Physical Address','Movies rented','Salutation'],data=[['1', 'Janet Jones','First Street Plot N0 4', 'Titanic', 'Ms.'],
                                                                                             ['1', 'Janet Jones','First Street Plot N0 4', 'The girl next door', 'Ms.'],
                                                                                             ['2','Robert Phil','3rd Street 34', 'Blade 3','Mr.'],
                                                                                             ['2','Robert Phil','3rd Street 34', 'Casablanca','Mr.'],
                                                                                             ['3','Robert Phil','5th Avenue', 'Titanic','Mr.']])
df
# Out:
#   ID   Full Names        Physical Address       Movies rented Salutation
# 0  1  Janet Jones  First Street Plot N0 4             Titanic        Ms.
# 1  1  Janet Jones  First Street Plot N0 4  The girl next door        Ms.
# 2  2  Robert Phil           3rd Street 34             Blade 3        Mr.
# 3  2  Robert Phil           3rd Street 34          Casablanca        Mr.
# 4  3  Robert Phil              5th Avenue             Titanic        Mr.

# %% [markdown]
# ## 2НФ

# %% [markdown]
# Primary key должен быть уникален!!!

# %%
df=pd.DataFrame(columns=['ID','Full Names','Physical Address','Salutation'],data=[['1', 'Janet Jones','First Street Plot N0 4', 'Ms.'],
                                                                                             ['2','Robert Phil','3rd Street 34', 'Mr.'],
                                                                                             ['3','Robert Phil','5th Avenue', 'Mr.']])
df
# Out:
#   ID   Full Names        Physical Address Salutation
# 0  1  Janet Jones  First Street Plot N0 4        Ms.
# 1  2  Robert Phil           3rd Street 34        Mr.
# 2  3  Robert Phil              5th Avenue        Mr.

# %%
df=pd.DataFrame(columns=['ID','Movies rented'],data=[['1','Titanic'],
                                                      ['1','The girl next door'],
                                                      ['2', 'Blade 3'],
                                                      ['2','Casablanca'],
                                                      ['3','Titanic']])
df
# Out:
#   ID       Movies rented
# 0  1             Titanic
# 1  1  The girl next door
# 2  2             Blade 3
# 3  2          Casablanca
# 4  3             Titanic

# %% [markdown]
# ## 3НФ

# %% [markdown]
# X = ID
#
# Y = Full Names
#
# Z = Salutation
#
# X --> Y , Y --> Z
#
# Z транзитивно зависит от X

# %%
df=pd.DataFrame(columns=['ID','Full Names','Physical Address'],data=[['1', 'Janet Jones','First Street Plot N0 4'],
                                                                                             ['2','Robert Phil','3rd Street 34'],
                                                                                             ['3','Robert Phil','5th Avenue']])
df
# Out:
#   ID   Full Names        Physical Address
# 0  1  Janet Jones  First Street Plot N0 4
# 1  2  Robert Phil           3rd Street 34
# 2  3  Robert Phil              5th Avenue

# %%
df=pd.DataFrame(columns=['ID','Movies rented'],data=[['1','Titanic'],
                                                      ['1','The girl next door'],
                                                      ['2', 'Blade 3'],
                                                      ['2','Casablanca'],
                                                      ['3','Titanic']])
df
# Out:
#   ID       Movies rented
# 0  1             Titanic
# 1  1  The girl next door
# 2  2             Blade 3
# 3  2          Casablanca
# 4  3             Titanic

# %%
df=pd.DataFrame(columns=['ID','Salutation'],data=[['1', 'Ms.'],
                                                  ['2','Mr.'],
                                                  ['3','Mr.']])
df
# Out:
#   ID Salutation
# 0  1        Ms.
# 1  2        Mr.
# 2  3        Mr.
