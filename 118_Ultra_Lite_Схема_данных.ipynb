# %% [markdown]
# <a href="https://colab.research.google.com/github/10100111/Display-of-HW1/blob/main/118_Ultra_Lite_%D0%A1%D1%85%D0%B5%D0%BC%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание Ultra Lite
#
#
# Используя схему данных, состоящую из таблиц Teachers, Students, Courses и StudentCourses , воспроизведите базу данных из занятия. И добавьте в нее таблицу, в которой есть три поля id (integer), campus (bit) и student_id (integer), которые говорят о том, проживает ли студент в кампусе или нет. Свяжите эту таблицу с таблицей StudentCourses.
#
# Для выполнения можно пользоваться любой программой по созданию баз данных (https://www.dbdesigner.net , https://www.quickdatabasediagrams.com , https://www.devart.com/ru/dbforge/sql/studio/database-diagram.html и т.д. ). Результат представить в виде картинки любого формата.
#
# Разбор: https://drive.google.com/file/d/1sojrpY5qPuImHzX_Y3C2f1UMmU5P8bft/view?usp=sharing

# %% [markdown]
# ![image.png](data:image/png;base64,...)
